# %%
import time
import calendar

# %%
# Import geopandas package
import geopandas as gpd
import pandas as pd
# Read in shapefile and examine data
contiguous_usa = gpd.read_file('data/cb_2018_us_state_20m.shp')
contiguous_usa.head()
from bokeh.plotting import output_notebook
output_notebook()
from datetime import date
today = date.today()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
colnames = ['DATE', 'VACCINATED', 'NAME']
state_thresholds = pd.read_csv (r'predicted_immunity.csv', names=colnames, header=None)
state_thresholds.head()
# Out:
#          DATE  VACCINATED        NAME
# 0  2021-04-14  11208025.0     Arizona
# 1  2022-08-06  59315081.0  California
# 2  2021-07-03   8690732.0    Colorado
# 3  2021-05-09  32723402.0     Florida
# 4  2021-04-13   2769848.0       Idaho

# %%
state_thresholds['DATE'] = pd.to_datetime(state_thresholds['DATE'])
state_thresholds = state_thresholds.set_index('DATE')

# %%
state_thresholds
# Out:
#             VACCINATED           NAME
# DATE
# 2021-04-14  11208025.0        Arizona
# 2022-08-06  59315081.0     California
# 2021-07-03   8690732.0       Colorado
# 2021-05-09  32723402.0        Florida
# 2021-04-13   2769848.0          Idaho
# 2021-05-10  19487074.0       Illinois
# 2021-07-30  10141963.0        Indiana
# 2021-04-23   4888471.0           Iowa
# 2021-05-15   4440122.0         Kansas
# 2021-06-26   6760775.0       Kentucky
# 2021-07-30   7039342.0      Louisiana
# 2021-06-23   2038952.0          Maine
# 2021-09-02   9110621.0       Maryland
# 2021-05-03  10513463.0  Massachusetts
# 2021-06-26  15056223.0       Michigan
# 2021-06-29   8558195.0      Minnesota
# 2021-06-06   4478124.0    Mississippi
# 2021-11-28   9239557.0       Missouri
# 2021-09-28   1608008.0        Montana
# 2021-07-09   2924738.0       Nebraska
# 2021-05-19   4634485.0         Nevada
# 2021-08-28   2051494.0  New Hampshire
# 2021-05-13  13546323.0     New Jersey
# 2022-06-17  29191709.0       New York
# 2021-06-27   1147104.0   North Dakota
# 2021-05-15  17685619.0           Ohio
# 2021-06-16   6335644.0         Oregon
# 2021-07-15  19229110.0   Pennsylvania
# 2021-07-21   1590270.0   Rhode Island
# 2021-05-01  44533370.0          Texas
# 2021-06-27   4871224.0           Utah
# 2021-08-14    936579.0        Vermont
# 2021-09-29  12836307.0       Virginia
# 2021-06-10   8816410.0      Wisconsin
# 2021-04-20    882251.0        Wyoming

# %%
didx = pd.DatetimeIndex(state_thresholds.index)

# %%
months = pd.DataFrame(columns=['monthname'])

test = pd.DatetimeIndex(state_thresholds.index[state_thresholds['NAME'] == 'Virginia']).month_name()

print('Month Name:' test)
# Out:
#   File "<ipython-input-44-5e81dcf3671f>", line 5
#     print('Month Name:' test)
#                         ^
# SyntaxError: invalid syntax

# %%
test
# Out:
# Index(['September'], dtype='object', name='DATE')
