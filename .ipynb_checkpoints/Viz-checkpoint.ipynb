# %%
# Import geopandas package
import geopandas as gpd
import pandas as pd
# Read in shapefile and examine data
contiguous_usa = gpd.read_file('data/cb_2018_us_state_20m.shp')
contiguous_usa.head()
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1203">Loading BokehJS ...</span>
#     </div>

# %%
colnames = ['DATE', 'VACCINATED', 'NAME']
state_thresholds = pd.read_csv (r'predicted_immunity.csv', names=colnames, header=None)
state_thresholds.head()
# Out:
#          DATE  VACCINATED        NAME
# 0  2021-04-14  11208025.0     Arizona
# 1  2022-08-06  59315081.0  California
# 2  2021-07-03   8690732.0    Colorado
# 3  2021-05-09  32723402.0     Florida
# 4  2021-04-13   2769848.0       Idaho

# %%
# Merge shapefile with population data
pop_states = contiguous_usa.merge(state_thresholds, left_on = 'NAME', right_on = 'NAME')

# Drop Alaska and Hawaii
pop_states = pop_states.loc[~pop_states['NAME'].isin(['Alaska', 'Hawaii'])]

# %%
import json
from bokeh.io import show
from bokeh.models import (CDSView, ColorBar, ColumnDataSource,
                          CustomJS, CustomJSFilter, 
                          GeoJSONDataSource, HoverTool,
                          LinearColorMapper, Slider)
from bokeh.layouts import column, row, widgetbox
from bokeh.palettes import brewer
from bokeh.plotting import figure
# Input GeoJSON source that contains features for plotting
geosource = GeoJSONDataSource(geojson = pop_states.to_json())

# %%
# Define color palettes
palette = brewer['Blues'][5]
palette = palette[::1] # reverse order of colors so higher values have darker colors
# Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 0, high = 40000000)
# Define custom tick labels for color bar.
tick_labels = {'0': '0', '5000000': '5,000,000',
 '10000000':'10,000,000', '15000000':'15,000,000',
 '20000000':'20,000,000', '25000000':'25,000,000',
 '30000000':'30,000,000', '35000000':'35,000,000',
 '40000000':'40,000,000+'}
# Create color bar.
color_bar = ColorBar(color_mapper = color_mapper, 
                     label_standoff = 8,
                     width = 500, height = 20,
                     border_line_color = None,
                     location = (0,0), 
                     orientation = 'horizontal',
                     major_label_overrides = tick_labels)
# Create figure object.
p = figure(title = 'Expected Herd Immunity', 
           plot_height = 600, plot_width = 950, 
           toolbar_location = 'below',
           tools = 'pan, wheel_zoom, box_zoom, reset')
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
# Add patch renderer to figure.
states = p.patches('xs','ys', source = geosource,
                   fill_color = {'field' :'VACCINATED',
                                 'transform' : color_mapper},
                   line_color = 'gray', 
                   line_width = 0.25, 
                   fill_alpha = 1)
# Create hover tool
p.add_tools(HoverTool(renderers = [states],
                      tooltips = [('State','@NAME'),
                               ('Total Vaccinated', '@VACCINATED'),
                                 ('Date:', '@DATE')]))
# Specify layout
# p.add_layout(color_bar, ‘below’)

show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-ed459edc41fd> in <module>
#      40 # p.add_layout(color_bar, ‘below’)
#      41
# ---> 42 show(p)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     137         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     138
# --> 139     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     140
#     141 #-----------------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     171
#     172     if state.notebook:
# --> 173         comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     174         shown = True
#     175
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kw)
#     296     if _HOOKS[notebook_type][action] is None:
#     297         raise RuntimeError("notebook hook for %r did not install %r action" % notebook_type, action)
# --> 298     return _HOOKS[notebook_type][action](*args, **kw)
#     299
#     300 #-----------------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/io/notebook.py in show_doc(obj, state, notebook_handle)
#     502     '''
#     503     if obj not in state.document.roots:
# --> 504         state.document.add_root(obj)
#     505
#     506     from ..embed.notebook import notebook_content
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/document/document.py in add_root(self, model, setter)
#     318             self._roots.append(model)
#     319         finally:
# --> 320             self._pop_all_models_freeze()
#     321         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     322
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/document/document.py in _pop_all_models_freeze(self)
#    1073         self._all_models_freeze_count -= 1
#    1074         if self._all_models_freeze_count == 0:
# -> 1075             self._recompute_all_models()
#    1076
#    1077     def _recompute_all_models(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/document/document.py in _recompute_all_models(self)
#    1096             d._detach_document()
#    1097         for a in to_attach:
# -> 1098             a._attach_document(self)
#    1099         self._all_models = recomputed
#    1100         self._all_models_by_name = recomputed_by_name
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/model.py in _attach_document(self, doc)
#     672         '''
#     673         if self._document is not None and self._document is not doc:
# --> 674             raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
#     675         doc.theme.apply_to_model(self)
#     676         self._document = doc
#
# RuntimeError: Models must be owned by only a single document, Selection(id='1044', ...) is already in a doc
